# %% [markdown]
# <B><text size = 14>Examination of Toronto Neighborhoods</b></text>

# %% [markdown]
# The link we need to scrape is: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %% [markdown]
# We will use the BeautifulSoup package to scrape this Wiki Page.

# %%
from bs4 import BeautifulSoup ## importing BeautifulSoup package 
import requests

# %%
source  = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").text ## requesting the text from the website
soup = BeautifulSoup(source,'lxml') ## storing this text as a beautifulSoup object

# %%
My_table = soup.find('table',{'class':'wikitable sortable'}) ## operating on our BeautifulSoup object to find the table in the text
table_body = My_table.find('tbody')
## table_body  ## checking table content to see if we got the right table

# %% [markdown]
# Importing the libraries for dataframes (the panda library) is important.  I also loaded the data into a .csv file to examine the entire set by eye.

# %%
import pandas as pd
l = []
for tr in table_body.findAll("tr"):
    td = tr.find_all('td')
    row = [tr.text for tr in td]
    l.append(row)
df = pd.DataFrame(l, columns=["Postcode","Borough", "Neighborhood"])
df
df.to_csv('check.csv')

# %% [markdown]
# I noticed theres some extra markup in the 'neighborhood' column so the function defined here gets rid of those pesky linebreaks.

# %%
def func(string):
    if string is not None:
        s = string.split("\n")
        return s[0]
    else:
        return string
## applying the function the column to chop off the pesky extra '/n' values
df['Neighborhood']= df['Neighborhood'].apply(func)

# %%
df.head()
# Out:
#   Postcode       Borough      Neighborhood
# 0     None          None              None
# 1      M1A  Not assigned      Not assigned
# 2      M2A  Not assigned      Not assigned
# 3      M3A    North York         Parkwoods
# 4      M4A    North York  Victoria Village

# %% [markdown]
# The first entry was all nones, so I chopped it off using the drop function on a dataframe.

# %%
df=df.drop(df.index[0])

# %% [markdown]
# Then I checked to make sure it is chopped off.

# %%
df.head()
# Out:
#   Postcode           Borough      Neighborhood
# 1      M1A      Not assigned      Not assigned
# 2      M2A      Not assigned      Not assigned
# 3      M3A        North York         Parkwoods
# 4      M4A        North York  Victoria Village
# 5      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# Now, I wanted to delete postal codes that had no borough and no neighbhorhood assigned to them.

# %%
##Here we create a new dataframe that is the same as the old one but without the postal codes that have neither a borough or neighborhood assigned.
df22 = pd.DataFrame()
for index, row in df.iterrows(): ## need to use iterrows to iterate through a dataframe
    if (df['Borough'][index]=="Not assigned" and df['Neighborhood'][index]=="Not assigned"):  
        None
    else:
        df22 = df22.append(({'Neighborhood': df['Neighborhood'][index],'Borough': df['Borough'][index],'Postcode': df['Postcode'][index]}), ignore_index=True)
df22.head()
df22.count()
# Out:
# Borough         211
# Neighborhood    211
# Postcode        211
# dtype: int64

# %% [markdown]
# Some postal codes had a borough but no neighborhood, so I just make the neighborhood equal to the borough.

# %%
##Creating a fresh data frame that will now have unassigned neighborhood values to the same as the borough
df222 = pd.DataFrame()
for index, row in df22.iterrows(): ## need to use iterrows to iterate through a dataframe
    if (df22['Neighborhood'][index]=="Not assigned"):  
        df222 = df222.append(({'Borough': df22['Borough'][index],'Neighborhood': df22['Borough'][index],'Postcode': df22['Postcode'][index]}), ignore_index=True)
    else:
        df222 = df222.append(({'Borough': df22['Borough'][index],'Neighborhood': df22['Neighborhood'][index],'Postcode': df22['Postcode'][index]}), ignore_index=True)
df22.head()
df22.count()
df222.to_csv('checkmiddle.csv')

# %% [markdown]
# Some postal codes are duplicates.  A postal code seems to only have one borough but it can have multiple neighborhoods.  Here, I wrote a function that first checks if the postal codes are the same.  If they are the same, it then checks if the neighborhoods are the same.  If the neighborhoods are the same in the string of the following entry, it's a duplicate entry so we stop there, and we don't append it to the new empty dataframe.  If the neighborhoods are different, we add the neighborhood to the next entry's string.  So we get a list of neighborhoods for each borough.

# %%
df2222 = pd.DataFrame()
for index, row in df222.iterrows():
    if(index != 210):
        if(df222['Postcode'][index]==df222['Postcode'][index+1]):
            if((df222['Neighborhood'][index]==((df222['Neighborhood'][index+1])))):
                None
            else:
                df222['Neighborhood'][index+1] = df222['Neighborhood'][index] + ", " + df222['Neighborhood'][index+1]
            
        else:
            df2222 = df2222.append(({'Borough': df222['Borough'][index],'Neighborhood': df222['Neighborhood'][index],'Postcode': df222['Postcode'][index]}), ignore_index=True)
    else:
         df2222 = df2222.append(({'Borough': df222['Borough'][index],'Neighborhood': df222['Neighborhood'][index],'Postcode': df222['Postcode'][index]}), ignore_index=True)
df2222.to_csv('checkend.csv')

# %% [markdown]
# We end up with 102 unique postal code values. It seems to look okay when I check it against the csvs.

# %%
df2222.shape
# Out:
# (103, 3)

# %%
df2222
# Out:
#               Borough                                       Neighborhood  \
# 0          North York                                          Parkwoods
# 1          North York                                   Victoria Village
# 2    Downtown Toronto                          Harbourfront, Regent Park
# 3          North York                   Lawrence Heights, Lawrence Manor
# 4        Queen's Park                                       Queen's Park
# 5           Etobicoke                                   Islington Avenue
# 6         Scarborough                                     Rouge, Malvern
# 7          North York                                    Don Mills North
# 8           East York                    Woodbine Gardens, Parkview Hill
# 9    Downtown Toronto                           Ryerson, Garden District
# 10         North York                                          Glencairn
# 11          Etobicoke  Cloverdale, Islington, Martin Grove, Princess ...
# 12        Scarborough             Highland Creek, Rouge Hill, Port Union
# 13         North York                   Flemingdon Park, Don Mills South
# 14          East York                                   Woodbine Heights
# 15   Downtown Toronto                                     St. James Town
# 16               York                                 Humewood-Cedarvale
# 17          Etobicoke  Bloordale Gardens, Eringate, Markland Wood, Ol...
# 18        Scarborough                  Guildwood, Morningside, West Hill
# 19       East Toronto                                        The Beaches
# 20   Downtown Toronto                                        Berczy Park
# 21               York                                Caledonia-Fairbanks
# 22        Scarborough                                             Woburn
# 23          East York                                            Leaside
# 24   Downtown Toronto                                 Central Bay Street
# 25   Downtown Toronto                                           Christie
# 26        Scarborough                                          Cedarbrae
# 27         North York                                  Hillcrest Village
# 28         North York    Bathurst Manor, Downsview North, Wilson Heights
# 29          East York                                   Thorncliffe Park
# ..                ...                                                ...
# 73    Central Toronto                                 North Toronto West
# 74    Central Toronto                The Annex, North Midtown, Yorkville
# 75       West Toronto                             Parkdale, Roncesvalles
# 76        Mississauga              Canada Post Gateway Processing Centre
# 77          Etobicoke  Kingsview Village, Martin Grove Gardens, Richv...
# 78        Scarborough                                          Agincourt
# 79    Central Toronto                                         Davisville
# 80   Downtown Toronto                     Harbord, University of Toronto
# 81       West Toronto                                 Runnymede, Swansea
# 82        Scarborough            Clarks Corners, Sullivan, Tam O'Shanter
# 83    Central Toronto                        Moore Park, Summerhill East
# 84   Downtown Toronto          Chinatown, Grange Park, Kensington Market
# 85        Scarborough  Agincourt North, L'Amoreaux East, Milliken, St...
# 86    Central Toronto  Deer Park, Forest Hill SE, Rathnelly, South Hi...
# 87   Downtown Toronto  CN Tower, Bathurst Quay, Island airport, Harbo...
# 88          Etobicoke       Humber Bay Shores, Mimico South, New Toronto
# 89          Etobicoke  Albion Gardens, Beaumond Heights, Humbergate, ...
# 90        Scarborough                                    L'Amoreaux West
# 91   Downtown Toronto                                           Rosedale
# 92   Downtown Toronto                    Stn A PO Boxes 25 The Esplanade
# 93          Etobicoke                             Alderwood, Long Branch
# 94          Etobicoke                                          Northwest
# 95        Scarborough                                        Upper Rouge
# 96   Downtown Toronto                        Cabbagetown, St. James Town
# 97   Downtown Toronto             First Canadian Place, Underground city
# 98          Etobicoke      The Kingsway, Montgomery Road, Old Mill North
# 99   Downtown Toronto                               Church and Wellesley
# 100      East Toronto  Business Reply Mail Processing Centre 969 Eastern
# 101         Etobicoke  Humber Bay, King's Mill Park, Kingsway Park So...
# 102         Etobicoke  Kingsway Park South West, Mimico NW, The Queen...
#
#     Postcode
# 0        M3A
# 1        M4A
# 2        M5A
# 3        M6A
# 4        M7A
# 5        M9A
# 6        M1B
# 7        M3B
# 8        M4B
# 9        M5B
# 10       M6B
# 11       M9B
# 12       M1C
# 13       M3C
# 14       M4C
# 15       M5C
# 16       M6C
# 17       M9C
# 18       M1E
# 19       M4E
# 20       M5E
# 21       M6E
# 22       M1G
# 23       M4G
# 24       M5G
# 25       M6G
# 26       M1H
# 27       M2H
# 28       M3H
# 29       M4H
# ..       ...
# 73       M4R
# 74       M5R
# 75       M6R
# 76       M7R
# 77       M9R
# 78       M1S
# 79       M4S
# 80       M5S
# 81       M6S
# 82       M1T
# 83       M4T
# 84       M5T
# 85       M1V
# 86       M4V
# 87       M5V
# 88       M8V
# 89       M9V
# 90       M1W
# 91       M4W
# 92       M5W
# 93       M8W
# 94       M9W
# 95       M1X
# 96       M4X
# 97       M5X
# 98       M8X
# 99       M4Y
# 100      M7Y
# 101      M8Y
# 102      M8Z
#
# [103 rows x 3 columns]

# %% [markdown]
# The shape was (103,3) and in case that is the wrong shape, I will show you that it looks to be right by printing the dataframe out for you.
#
# Now we create a new dataframe with the geo-coords.

# %%
import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

# %%
geocode = Nominatim(user_agent="toronto_explorer")

# %% [markdown]
# I couldn't for the life of me figure out how to input a postalcode into the geolocater.geocode function, so I just passed the borough with "ON, Canada" tagged onto it.  Maybe I will see how other people did it... It just doesn't seem correct to pass the borough only but that's all I could figure out since postcode didn't seem to be a valid input.

# %%
data_frame_with_coords = pd.DataFrame()
for index, row in df2222.iterrows():
    address = df2222['Borough'][index] + ', ON, Canada'
    geolocator = Nominatim(user_agent="toronto_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    data_frame_with_coords = data_frame_with_coords.append(({'Borough': df2222['Borough'][index],'Neighborhood': df2222['Neighborhood'][index],'Postcode': df2222['Postcode'][index], 'Latitude': latitude, 'Longitude': longitude}), ignore_index=True)

# %%
data_frame_with_coords
# Out:
#               Borough   Latitude  Longitude  \
# 0          North York  43.770817 -79.413300
# 1          North York  43.770817 -79.413300
# 2    Downtown Toronto  43.655115 -79.380219
# 3          North York  43.770817 -79.413300
# 4        Queen's Park  43.659980 -79.390369
# 5           Etobicoke  43.671459 -79.552492
# 6         Scarborough  43.773077 -79.257774
# 7          North York  43.770817 -79.413300
# 8           East York  43.691339 -79.327821
# 9    Downtown Toronto  43.655115 -79.380219
# 10         North York  43.770817 -79.413300
# 11          Etobicoke  43.671459 -79.552492
# 12        Scarborough  43.773077 -79.257774
# 13         North York  43.770817 -79.413300
# 14          East York  43.691339 -79.327821
# 15   Downtown Toronto  43.655115 -79.380219
# 16               York  44.000752 -79.437222
# 17          Etobicoke  43.671459 -79.552492
# 18        Scarborough  43.773077 -79.257774
# 19       East Toronto  43.624790 -79.393492
# 20   Downtown Toronto  43.655115 -79.380219
# 21               York  44.000752 -79.437222
# 22        Scarborough  43.773077 -79.257774
# 23          East York  43.691339 -79.327821
# 24   Downtown Toronto  43.655115 -79.380219
# 25   Downtown Toronto  43.655115 -79.380219
# 26        Scarborough  43.773077 -79.257774
# 27         North York  43.770817 -79.413300
# 28         North York  43.770817 -79.413300
# 29          East York  43.691339 -79.327821
# ..                ...        ...        ...
# 73    Central Toronto  43.653963 -79.387207
# 74    Central Toronto  43.653963 -79.387207
# 75       West Toronto  43.653963 -79.387207
# 76        Mississauga  43.590338 -79.645729
# 77          Etobicoke  43.671459 -79.552492
# 78        Scarborough  43.773077 -79.257774
# 79    Central Toronto  43.653963 -79.387207
# 80   Downtown Toronto  43.655115 -79.380219
# 81       West Toronto  43.653963 -79.387207
# 82        Scarborough  43.773077 -79.257774
# 83    Central Toronto  43.653963 -79.387207
# 84   Downtown Toronto  43.655115 -79.380219
# 85        Scarborough  43.773077 -79.257774
# 86    Central Toronto  43.653963 -79.387207
# 87   Downtown Toronto  43.655115 -79.380219
# 88          Etobicoke  43.671459 -79.552492
# 89          Etobicoke  43.671459 -79.552492
# 90        Scarborough  43.773077 -79.257774
# 91   Downtown Toronto  43.655115 -79.380219
# 92   Downtown Toronto  43.655115 -79.380219
# 93          Etobicoke  43.671459 -79.552492
# 94          Etobicoke  43.671459 -79.552492
# 95        Scarborough  43.773077 -79.257774
# 96   Downtown Toronto  43.655115 -79.380219
# 97   Downtown Toronto  43.655115 -79.380219
# 98          Etobicoke  43.671459 -79.552492
# 99   Downtown Toronto  43.655115 -79.380219
# 100      East Toronto  43.624790 -79.393492
# 101         Etobicoke  43.671459 -79.552492
# 102         Etobicoke  43.671459 -79.552492
#
#                                           Neighborhood Postcode
# 0                                            Parkwoods      M3A
# 1                                     Victoria Village      M4A
# 2                            Harbourfront, Regent Park      M5A
# 3                     Lawrence Heights, Lawrence Manor      M6A
# 4                                         Queen's Park      M7A
# 5                                     Islington Avenue      M9A
# 6                                       Rouge, Malvern      M1B
# 7                                      Don Mills North      M3B
# 8                      Woodbine Gardens, Parkview Hill      M4B
# 9                             Ryerson, Garden District      M5B
# 10                                           Glencairn      M6B
# 11   Cloverdale, Islington, Martin Grove, Princess ...      M9B
# 12              Highland Creek, Rouge Hill, Port Union      M1C
# 13                    Flemingdon Park, Don Mills South      M3C
# 14                                    Woodbine Heights      M4C
# 15                                      St. James Town      M5C
# 16                                  Humewood-Cedarvale      M6C
# 17   Bloordale Gardens, Eringate, Markland Wood, Ol...      M9C
# 18                   Guildwood, Morningside, West Hill      M1E
# 19                                         The Beaches      M4E
# 20                                         Berczy Park      M5E
# 21                                 Caledonia-Fairbanks      M6E
# 22                                              Woburn      M1G
# 23                                             Leaside      M4G
# 24                                  Central Bay Street      M5G
# 25                                            Christie      M6G
# 26                                           Cedarbrae      M1H
# 27                                   Hillcrest Village      M2H
# 28     Bathurst Manor, Downsview North, Wilson Heights      M3H
# 29                                    Thorncliffe Park      M4H
# ..                                                 ...      ...
# 73                                  North Toronto West      M4R
# 74                 The Annex, North Midtown, Yorkville      M5R
# 75                              Parkdale, Roncesvalles      M6R
# 76               Canada Post Gateway Processing Centre      M7R
# 77   Kingsview Village, Martin Grove Gardens, Richv...      M9R
# 78                                           Agincourt      M1S
# 79                                          Davisville      M4S
# 80                      Harbord, University of Toronto      M5S
# 81                                  Runnymede, Swansea      M6S
# 82             Clarks Corners, Sullivan, Tam O'Shanter      M1T
# 83                         Moore Park, Summerhill East      M4T
# 84           Chinatown, Grange Park, Kensington Market      M5T
# 85   Agincourt North, L'Amoreaux East, Milliken, St...      M1V
# 86   Deer Park, Forest Hill SE, Rathnelly, South Hi...      M4V
# 87   CN Tower, Bathurst Quay, Island airport, Harbo...      M5V
# 88        Humber Bay Shores, Mimico South, New Toronto      M8V
# 89   Albion Gardens, Beaumond Heights, Humbergate, ...      M9V
# 90                                     L'Amoreaux West      M1W
# 91                                            Rosedale      M4W
# 92                     Stn A PO Boxes 25 The Esplanade      M5W
# 93                              Alderwood, Long Branch      M8W
# 94                                           Northwest      M9W
# 95                                         Upper Rouge      M1X
# 96                         Cabbagetown, St. James Town      M4X
# 97              First Canadian Place, Underground city      M5X
# 98       The Kingsway, Montgomery Road, Old Mill North      M8X
# 99                                Church and Wellesley      M4Y
# 100  Business Reply Mail Processing Centre 969 Eastern      M7Y
# 101  Humber Bay, King's Mill Park, Kingsway Park So...      M8Y
# 102  Kingsway Park South West, Mimico NW, The Queen...      M8Z
#
# [103 rows x 5 columns]
